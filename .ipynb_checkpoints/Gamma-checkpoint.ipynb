# %% [markdown]
# # Generate gamma

# %%
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
import scipy.io.wavfile as wavfile
import sys
sns.set()
np.set_printoptions(threshold=sys.maxsize)
plt.rcParams['figure.dpi'] = 600
plt.rcParams['figure.figsize'] = (10, 3)

# %% [markdown]
# ### Twelve-tone equal temperament

# %% [markdown]
# f(i) = f_0 * 2^(i/12)<br/>
# f(i) - the pitch, or frequency (usually in hertz), we need to find;<br/>
# f_0 - the frequency of the reference pitch.

# %% [markdown]
# The reference pitch also known as Stuttgart pitch is A4, the 49th key from the left end of a piano, tuned to 440 Hz.<br/>

# %% [markdown]
# For the First octave we have the following notation of notes:<br/>
# C4 -- 40th key <br/>
# D4 -- 42th key <br/>
# E4 -- 44th key <br/>
# F4 -- 45th key <br/>
# G4 -- 47th key <br/>
# A4 -- 49th key <br/>
# B4 -- 51th key .

# %%
A4 = 440

# %%
gamma_C_major = {'C4' : 40,
                'D4': 42,
                'E4' : 44,
                'F4' : 45,
                'G4' : 47,
                'A4': 49,
                'B4' : 51}

# %%
freq_1octave = dict()
for k, v in gamma_C_major.items():
    freq_1octave[k] = A4 * (2 ** ((v - gamma_C_major['A4']) / 12))
freq_1octave
# Out:
# {'A4': 440.0,
#  'B4': 493.8833012561241,
#  'C4': 261.6255653005986,
#  'D4': 293.6647679174076,
#  'E4': 329.6275569128699,
#  'F4': 349.2282314330039,
#  'G4': 391.99543598174927}

# %%
sample_rate = 44100 # sample rate
sample_period = 1 / sample_rate # sample period
t = 1 # seconds of sampling
N = sample_rate * t # total points in signal
t_vec = np.arange(N) * sample_period

# %% [markdown]
# ## Sine Wave Sampling

# %%
notes = [np.sin( 2 * np.pi * v * t_vec) for v in freq_1octave.values()]
gamma = np.concatenate(notes)

plt.plot(gamma[::2000], 'g')
plt.xlabel("Time -->")
plt.ylabel("<-- Signal -->")
plt.show()

# %%
normalized_gamma = np.int16((gamma / gamma.max()) * 32767)
wavfile.write('sine_waves_c_major.wav', sample_rate, normalized_gamma)
print("Generated notes were saved to file: sine_waves_c_major.wav")
# Out:
# Generated notes were saved to file: sine_waves_c_major.wav

# %% [markdown]
# ## Inverse Fourier Transformation

# %%
notes = []
for v in freq_1octave.values():
    A = np.zeros(int(sample_rate / 2))
    A[int(v)] = sample_rate / 2
    note = np.fft.irfft(spectre)
    notes.append(np.tile(note, t))

gamma = np.concatenate(notes)

plt.plot(gamma[::2000], 'g')
plt.xlabel("Time -->")
plt.ylabel("<-- Signal -->")
plt.show()


wavfile.write('fourier_trans.wav', sample_rate, gamma)

# %%
sampFreq, sound = wavfile.read('sine_waves_c_major.wav',)
sound = sound / 2.0**15
length_in_s = sound.shape[0] / sampFreq
plt.plot(sound[::700], 'r')
plt.tight_layout()
plt.show()

# %%
time = np.arange(sound.shape[0]) / sound.shape[0] * length_in_s
T = time[::700]
sig = sound[::700]
plt.plot(T[:150], sig[:150], 'black')
plt.xlabel("Time -->")
plt.ylabel("<-- Signal -->")
plt.tight_layout()
plt.show()

# %%
fft_spectrum = np.fft.rfft(sound)
frequencies = np.fft.rfftfreq(sound.size, d=1./sampFreq)
fft_spectrum_abs = np.abs(fft_spectrum)
plt.plot(frequencies, fft_spectrum_abs, 'red')
plt.xlabel("frequency, Hz")
plt.ylabel("Amplitude, units")
plt.show()

# %%
plt.plot(frequencies[1500:4000], fft_spectrum_abs[1500:4000])
plt.xlabel("Frequency")
plt.ylabel("Amplitude")
plt.show()

# %%
for i,f in enumerate(fft_spectrum_abs):
    if f > 350: #looking at amplitudes of the spikes higher than 350 
        print('frequency = {} Hz with amplitude {} '.format(np.round(frequencies[i],1),  np.round(f)))
# Out:
# frequency = 220.0 Hz with amplitude 350.0
# frequency = 221.0 Hz with amplitude 356.0
# frequency = 222.0 Hz with amplitude 362.0
# frequency = 223.0 Hz with amplitude 368.0
# frequency = 224.0 Hz with amplitude 374.0
# frequency = 225.0 Hz with amplitude 381.0
# frequency = 226.0 Hz with amplitude 387.0
# frequency = 227.0 Hz with amplitude 395.0
# frequency = 228.0 Hz with amplitude 402.0
# frequency = 229.0 Hz with amplitude 410.0
# frequency = 230.0 Hz with amplitude 419.0
# frequency = 231.0 Hz with amplitude 428.0
# frequency = 232.0 Hz with amplitude 437.0
# frequency = 233.0 Hz with amplitude 447.0
# frequency = 234.0 Hz with amplitude 457.0
# frequency = 235.0 Hz with amplitude 469.0
# frequency = 236.0 Hz with amplitude 481.0
# frequency = 237.0 Hz with amplitude 494.0
# frequency = 238.0 Hz with amplitude 508.0
# frequency = 238.1 Hz with amplitude 355.0
# frequency = 239.0 Hz with amplitude 522.0
# frequency = 239.1 Hz with amplitude 369.0
# frequency = 240.0 Hz with amplitude 539.0
# frequency = 240.1 Hz with amplitude 384.0
# frequency = 241.0 Hz with amplitude 556.0
# frequency = 241.1 Hz with amplitude 400.0
# frequency = 242.0 Hz with amplitude 575.0
# frequency = 242.1 Hz with amplitude 418.0
# frequency = 242.9 Hz with amplitude 357.0
# frequency = 243.0 Hz with amplitude 596.0
# frequency = 243.1 Hz with amplitude 438.0
# frequency = 243.9 Hz with amplitude 371.0
# frequency = 244.0 Hz with amplitude 619.0
# frequency = 244.1 Hz with amplitude 461.0
# frequency = 244.9 Hz with amplitude 386.0
# frequency = 245.0 Hz with amplitude 645.0
# frequency = 245.1 Hz with amplitude 486.0
# frequency = 245.9 Hz with amplitude 402.0
# frequency = 246.0 Hz with amplitude 673.0
# frequency = 246.1 Hz with amplitude 514.0
# frequency = 246.9 Hz with amplitude 421.0
# frequency = 247.0 Hz with amplitude 705.0
# frequency = 247.1 Hz with amplitude 545.0
# frequency = 247.3 Hz with amplitude 371.0
# frequency = 247.9 Hz with amplitude 443.0
# frequency = 248.0 Hz with amplitude 742.0
# frequency = 248.1 Hz with amplitude 582.0
# frequency = 248.3 Hz with amplitude 401.0
# frequency = 248.9 Hz with amplitude 469.0
# frequency = 249.0 Hz with amplitude 783.0
# frequency = 249.1 Hz with amplitude 624.0
# frequency = 249.3 Hz with amplitude 437.0
# frequency = 249.9 Hz with amplitude 498.0
# frequency = 250.0 Hz with amplitude 832.0
# frequency = 250.1 Hz with amplitude 673.0
# frequency = 250.3 Hz with amplitude 479.0
# frequency = 250.9 Hz with amplitude 533.0
# frequency = 251.0 Hz with amplitude 888.0
# frequency = 251.1 Hz with amplitude 732.0
# frequency = 251.3 Hz with amplitude 530.0
# frequency = 251.9 Hz with amplitude 576.0
# frequency = 252.0 Hz with amplitude 956.0
# frequency = 252.1 Hz with amplitude 803.0
# frequency = 252.3 Hz with amplitude 592.0
# frequency = 252.4 Hz with amplitude 380.0
# frequency = 252.9 Hz with amplitude 628.0
# frequency = 253.0 Hz with amplitude 1039.0
# frequency = 253.1 Hz with amplitude 891.0
# frequency = 253.3 Hz with amplitude 669.0
# frequency = 253.4 Hz with amplitude 432.0
# frequency = 253.9 Hz with amplitude 694.0
# frequency = 254.0 Hz with amplitude 1142.0
# frequency = 254.1 Hz with amplitude 1001.0
# frequency = 254.3 Hz with amplitude 767.0
# frequency = 254.4 Hz with amplitude 499.0
# frequency = 254.9 Hz with amplitude 780.0
# frequency = 255.0 Hz with amplitude 1276.0
# frequency = 255.1 Hz with amplitude 1146.0
# frequency = 255.3 Hz with amplitude 897.0
# frequency = 255.4 Hz with amplitude 588.0
# frequency = 255.9 Hz with amplitude 896.0
# frequency = 256.0 Hz with amplitude 1455.0
# frequency = 256.1 Hz with amplitude 1344.0
# frequency = 256.3 Hz with amplitude 1076.0
# frequency = 256.4 Hz with amplitude 713.0
# frequency = 256.7 Hz with amplitude 359.0
# frequency = 256.9 Hz with amplitude 1062.0
# frequency = 257.0 Hz with amplitude 1710.0
# frequency = 257.1 Hz with amplitude 1629.0
# frequency = 257.3 Hz with amplitude 1338.0
# frequency = 257.4 Hz with amplitude 897.0
# frequency = 257.7 Hz with amplitude 459.0
# frequency = 257.9 Hz with amplitude 1318.0
# frequency = 258.0 Hz with amplitude 2102.0
# frequency = 258.1 Hz with amplitude 2078.0
# frequency = 258.3 Hz with amplitude 1760.0
# frequency = 258.4 Hz with amplitude 1198.0
# frequency = 258.7 Hz with amplitude 627.0
# frequency = 258.9 Hz with amplitude 1761.0
# frequency = 259.0 Hz with amplitude 2789.0
# frequency = 259.1 Hz with amplitude 2889.0
# frequency = 259.3 Hz with amplitude 2543.0
# frequency = 259.4 Hz with amplitude 1775.0
# frequency = 259.6 Hz with amplitude 492.0
# frequency = 259.7 Hz with amplitude 972.0
# frequency = 259.9 Hz with amplitude 2709.0
# frequency = 260.0 Hz with amplitude 4314.0
# frequency = 260.1 Hz with amplitude 4792.0
# frequency = 260.3 Hz with amplitude 4501.0
# frequency = 260.4 Hz with amplitude 3320.0
# frequency = 260.6 Hz with amplitude 1037.0
# frequency = 260.7 Hz with amplitude 2079.0
# frequency = 260.9 Hz with amplitude 6138.0
# frequency = 261.0 Hz with amplitude 10692.0
# frequency = 261.1 Hz with amplitude 14583.0
# frequency = 261.3 Hz with amplitude 18001.0
# frequency = 261.4 Hz with amplitude 20584.0
# frequency = 261.6 Hz with amplitude 21850.0
# frequency = 261.7 Hz with amplitude 21806.0
# frequency = 261.9 Hz with amplitude 20097.0
# frequency = 262.0 Hz with amplitude 16963.0
# frequency = 262.1 Hz with amplitude 13483.0
# frequency = 262.3 Hz with amplitude 9409.0
# frequency = 262.4 Hz with amplitude 5158.0
# frequency = 262.6 Hz with amplitude 1352.0
# frequency = 262.7 Hz with amplitude 1816.0
# frequency = 262.9 Hz with amplitude 3740.0
# frequency = 263.0 Hz with amplitude 4365.0
# frequency = 263.1 Hz with amplitude 4555.0
# frequency = 263.3 Hz with amplitude 3803.0
# frequency = 263.4 Hz with amplitude 2349.0
# frequency = 263.6 Hz with amplitude 710.0
# frequency = 263.7 Hz with amplitude 969.0
# frequency = 263.9 Hz with amplitude 2050.0
# frequency = 264.0 Hz with amplitude 2371.0
# frequency = 264.1 Hz with amplitude 2721.0
# frequency = 264.3 Hz with amplitude 2415.0
# frequency = 264.4 Hz with amplitude 1547.0
# frequency = 264.6 Hz with amplitude 506.0
# frequency = 264.7 Hz with amplitude 671.0
# frequency = 264.9 Hz with amplitude 1411.0
# frequency = 265.0 Hz with amplitude 1554.0
# frequency = 265.1 Hz with amplitude 1931.0
# frequency = 265.3 Hz with amplitude 1789.0
# frequency = 265.4 Hz with amplitude 1170.0
# frequency = 265.6 Hz with amplitude 407.0
# frequency = 265.7 Hz with amplitude 520.0
# frequency = 265.9 Hz with amplitude 1080.0
# frequency = 266.0 Hz with amplitude 1106.0
# frequency = 266.1 Hz with amplitude 1492.0
# frequency = 266.3 Hz with amplitude 1434.0
# frequency = 266.4 Hz with amplitude 951.0
# frequency = 266.7 Hz with amplitude 429.0
# frequency = 266.9 Hz with amplitude 880.0
# frequency = 267.0 Hz with amplitude 820.0
# frequency = 267.1 Hz with amplitude 1214.0
# frequency = 267.3 Hz with amplitude 1207.0
# frequency = 267.4 Hz with amplitude 810.0
# frequency = 267.7 Hz with amplitude 368.0
# frequency = 267.9 Hz with amplitude 749.0
# frequency = 268.0 Hz with amplitude 621.0
# frequency = 268.1 Hz with amplitude 1022.0
# frequency = 268.3 Hz with amplitude 1050.0
# frequency = 268.4 Hz with amplitude 712.0
# frequency = 268.9 Hz with amplitude 658.0
# frequency = 269.0 Hz with amplitude 472.0
# frequency = 269.1 Hz with amplitude 884.0
# frequency = 269.3 Hz with amplitude 937.0
# frequency = 269.4 Hz with amplitude 642.0
# frequency = 269.9 Hz with amplitude 593.0
# frequency = 270.0 Hz with amplitude 355.0
# frequency = 270.1 Hz with amplitude 779.0
# frequency = 270.3 Hz with amplitude 853.0
# frequency = 270.4 Hz with amplitude 589.0
# frequency = 270.9 Hz with amplitude 547.0
# frequency = 271.1 Hz with amplitude 699.0
# frequency = 271.3 Hz with amplitude 788.0
# frequency = 271.4 Hz with amplitude 549.0
# frequency = 271.9 Hz with amplitude 513.0
# frequency = 272.1 Hz with amplitude 637.0
# frequency = 272.3 Hz with amplitude 739.0
# frequency = 272.4 Hz with amplitude 519.0
# frequency = 272.9 Hz with amplitude 489.0
# frequency = 273.1 Hz with amplitude 589.0
# frequency = 273.3 Hz with amplitude 700.0
# frequency = 273.4 Hz with amplitude 496.0
# frequency = 273.9 Hz with amplitude 473.0
# frequency = 274.1 Hz with amplitude 553.0
# frequency = 274.3 Hz with amplitude 672.0
# frequency = 274.4 Hz with amplitude 479.0
# frequency = 274.9 Hz with amplitude 464.0
# frequency = 275.1 Hz with amplitude 526.0
# frequency = 275.3 Hz with amplitude 650.0
# frequency = 275.4 Hz with amplitude 467.0
# frequency = 275.9 Hz with amplitude 459.0
# frequency = 276.1 Hz with amplitude 507.0
# frequency = 276.3 Hz with amplitude 636.0
# frequency = 276.4 Hz with amplitude 460.0
# frequency = 276.9 Hz with amplitude 459.0
# frequency = 277.1 Hz with amplitude 497.0
# frequency = 277.3 Hz with amplitude 628.0
# frequency = 277.4 Hz with amplitude 457.0
# frequency = 277.9 Hz with amplitude 464.0
# frequency = 278.1 Hz with amplitude 495.0
# frequency = 278.3 Hz with amplitude 627.0
# frequency = 278.4 Hz with amplitude 458.0
# frequency = 278.9 Hz with amplitude 472.0
# frequency = 279.1 Hz with amplitude 500.0
# frequency = 279.3 Hz with amplitude 631.0
# frequency = 279.4 Hz with amplitude 464.0
# frequency = 279.9 Hz with amplitude 485.0
# frequency = 280.1 Hz with amplitude 514.0
# frequency = 280.3 Hz with amplitude 642.0
# frequency = 280.4 Hz with amplitude 474.0
# frequency = 280.9 Hz with amplitude 502.0
# frequency = 281.1 Hz with amplitude 536.0
# frequency = 281.3 Hz with amplitude 660.0
# frequency = 281.4 Hz with amplitude 490.0
# frequency = 281.9 Hz with amplitude 524.0
# frequency = 282.0 Hz with amplitude 397.0
# frequency = 282.1 Hz with amplitude 569.0
# frequency = 282.3 Hz with amplitude 687.0
# frequency = 282.4 Hz with amplitude 511.0
# frequency = 282.9 Hz with amplitude 551.0
# frequency = 283.0 Hz with amplitude 463.0
# frequency = 283.1 Hz with amplitude 613.0
# frequency = 283.3 Hz with amplitude 724.0
# frequency = 283.4 Hz with amplitude 541.0
# frequency = 283.9 Hz with amplitude 586.0
# frequency = 284.0 Hz with amplitude 539.0
# frequency = 284.1 Hz with amplitude 671.0
# frequency = 284.3 Hz with amplitude 774.0
# frequency = 284.4 Hz with amplitude 580.0
# frequency = 284.9 Hz with amplitude 629.0
# frequency = 285.0 Hz with amplitude 627.0
# frequency = 285.1 Hz with amplitude 747.0
# frequency = 285.3 Hz with amplitude 841.0
# frequency = 285.4 Hz with amplitude 631.0
# frequency = 285.9 Hz with amplitude 685.0
# frequency = 286.0 Hz with amplitude 733.0
# frequency = 286.1 Hz with amplitude 848.0
# frequency = 286.3 Hz with amplitude 931.0
# frequency = 286.4 Hz with amplitude 701.0
# frequency = 286.6 Hz with amplitude 363.0
# frequency = 286.9 Hz with amplitude 758.0
# frequency = 287.0 Hz with amplitude 866.0
# frequency = 287.1 Hz with amplitude 984.0
# frequency = 287.3 Hz with amplitude 1055.0
# frequency = 287.4 Hz with amplitude 796.0
# frequency = 287.6 Hz with amplitude 406.0
# frequency = 287.9 Hz with amplitude 858.0
# frequency = 288.0 Hz with amplitude 1041.0
# frequency = 288.1 Hz with amplitude 1172.0
# frequency = 288.3 Hz with amplitude 1231.0
# frequency = 288.4 Hz with amplitude 932.0
# frequency = 288.6 Hz with amplitude 468.0
# frequency = 288.9 Hz with amplitude 999.0
# frequency = 289.0 Hz with amplitude 1284.0
# frequency = 289.1 Hz with amplitude 1447.0
# frequency = 289.3 Hz with amplitude 1495.0
# frequency = 289.4 Hz with amplitude 1137.0
# frequency = 289.6 Hz with amplitude 561.0
# frequency = 289.9 Hz with amplitude 1215.0
# frequency = 290.0 Hz with amplitude 1653.0
# frequency = 290.1 Hz with amplitude 1882.0
# frequency = 290.3 Hz with amplitude 1923.0
# frequency = 290.4 Hz with amplitude 1474.0
# frequency = 290.6 Hz with amplitude 717.0
# frequency = 290.9 Hz with amplitude 1586.0
# frequency = 291.0 Hz with amplitude 2289.0
# frequency = 291.1 Hz with amplitude 2666.0
# frequency = 291.3 Hz with amplitude 2721.0
# frequency = 291.4 Hz with amplitude 2120.0
# frequency = 291.6 Hz with amplitude 1026.0
# frequency = 291.7 Hz with amplitude 508.0
# frequency = 291.9 Hz with amplitude 2370.0
# frequency = 292.0 Hz with amplitude 3676.0
# frequency = 292.1 Hz with amplitude 4487.0
# frequency = 292.3 Hz with amplitude 4696.0
# frequency = 292.4 Hz with amplitude 3828.0
# frequency = 292.6 Hz with amplitude 1908.0
# frequency = 292.7 Hz with amplitude 1077.0
# frequency = 292.9 Hz with amplitude 5099.0
# frequency = 293.0 Hz with amplitude 9198.0
# frequency = 293.1 Hz with amplitude 13298.0
# frequency = 293.3 Hz with amplitude 17153.0
# frequency = 293.4 Hz with amplitude 20063.0
# frequency = 293.6 Hz with amplitude 21782.0
# frequency = 293.7 Hz with amplitude 22042.0
# frequency = 293.9 Hz with amplitude 20574.0
# frequency = 294.0 Hz with amplitude 18159.0
# frequency = 294.1 Hz with amplitude 14766.0
# frequency = 294.3 Hz with amplitude 10549.0
# frequency = 294.4 Hz with amplitude 6235.0
# frequency = 294.6 Hz with amplitude 2195.0
# frequency = 294.7 Hz with amplitude 1133.0
# frequency = 294.9 Hz with amplitude 3192.0
# frequency = 295.0 Hz with amplitude 4523.0
# frequency = 295.1 Hz with amplitude 4860.0
# frequency = 295.3 Hz with amplitude 4085.0
# frequency = 295.4 Hz with amplitude 2723.0
# frequency = 295.6 Hz with amplitude 1028.0
# frequency = 295.7 Hz with amplitude 640.0
# frequency = 295.9 Hz with amplitude 1671.0
# frequency = 296.0 Hz with amplitude 2557.0
# frequency = 296.1 Hz with amplitude 2952.0
# frequency = 296.3 Hz with amplitude 2562.0
# frequency = 296.4 Hz with amplitude 1758.0
# frequency = 296.6 Hz with amplitude 668.0
# frequency = 296.7 Hz with amplitude 477.0
# frequency = 296.9 Hz with amplitude 1108.0
# frequency = 297.0 Hz with amplitude 1763.0
# frequency = 297.1 Hz with amplitude 2143.0
# frequency = 297.3 Hz with amplitude 1886.0
# frequency = 297.4 Hz with amplitude 1311.0
# frequency = 297.6 Hz with amplitude 496.0
# frequency = 297.7 Hz with amplitude 400.0
# frequency = 297.9 Hz with amplitude 817.0
# frequency = 298.0 Hz with amplitude 1331.0
# frequency = 298.1 Hz with amplitude 1696.0
# frequency = 298.3 Hz with amplitude 1507.0
# frequency = 298.4 Hz with amplitude 1054.0
# frequency = 298.6 Hz with amplitude 397.0
# frequency = 298.7 Hz with amplitude 356.0
# frequency = 298.9 Hz with amplitude 644.0
# frequency = 299.0 Hz with amplitude 1057.0
# frequency = 299.1 Hz with amplitude 1414.0
# frequency = 299.3 Hz with amplitude 1267.0
# frequency = 299.4 Hz with amplitude 890.0
# frequency = 299.9 Hz with amplitude 531.0
# frequency = 300.0 Hz with amplitude 867.0
# frequency = 300.1 Hz with amplitude 1220.0
# frequency = 300.3 Hz with amplitude 1103.0
# frequency = 300.4 Hz with amplitude 777.0
# frequency = 300.9 Hz with amplitude 455.0
# frequency = 301.0 Hz with amplitude 725.0
# frequency = 301.1 Hz with amplitude 1080.0
# frequency = 301.3 Hz with amplitude 985.0
# frequency = 301.4 Hz with amplitude 696.0
# frequency = 301.9 Hz with amplitude 403.0
# frequency = 302.0 Hz with amplitude 615.0
# frequency = 302.1 Hz with amplitude 973.0
# frequency = 302.3 Hz with amplitude 897.0
# frequency = 302.4 Hz with amplitude 635.0
# frequency = 302.9 Hz with amplitude 369.0
# frequency = 303.0 Hz with amplitude 527.0
# frequency = 303.1 Hz with amplitude 891.0
# frequency = 303.3 Hz with amplitude 831.0
# frequency = 303.4 Hz with amplitude 589.0
# frequency = 304.0 Hz with amplitude 454.0
# frequency = 304.1 Hz with amplitude 825.0
# frequency = 304.3 Hz with amplitude 779.0
# frequency = 304.4 Hz with amplitude 554.0
# frequency = 305.0 Hz with amplitude 392.0
# frequency = 305.1 Hz with amplitude 773.0
# frequency = 305.3 Hz with amplitude 739.0
# frequency = 305.4 Hz with amplitude 526.0
# frequency = 306.1 Hz with amplitude 731.0
# frequency = 306.3 Hz with amplitude 708.0
# frequency = 306.4 Hz with amplitude 505.0
# frequency = 307.1 Hz with amplitude 697.0
# frequency = 307.3 Hz with amplitude 685.0
# frequency = 307.4 Hz with amplitude 490.0
# frequency = 308.1 Hz with amplitude 669.0
# frequency = 308.3 Hz with amplitude 668.0
# frequency = 308.4 Hz with amplitude 478.0
# frequency = 309.1 Hz with amplitude 648.0
# frequency = 309.3 Hz with amplitude 655.0
# frequency = 309.4 Hz with amplitude 471.0
# frequency = 309.9 Hz with amplitude 355.0
# frequency = 310.1 Hz with amplitude 631.0
# frequency = 310.3 Hz with amplitude 648.0
# frequency = 310.4 Hz with amplitude 467.0
# frequency = 310.9 Hz with amplitude 370.0
# frequency = 311.1 Hz with amplitude 620.0
# frequency = 311.3 Hz with amplitude 645.0
# frequency = 311.4 Hz with amplitude 466.0
# frequency = 311.9 Hz with amplitude 387.0
# frequency = 312.1 Hz with amplitude 613.0
# frequency = 312.3 Hz with amplitude 647.0
# frequency = 312.4 Hz with amplitude 468.0
# frequency = 312.9 Hz with amplitude 408.0
# frequency = 313.1 Hz with amplitude 611.0
# frequency = 313.3 Hz with amplitude 653.0
# frequency = 313.4 Hz with amplitude 473.0
# frequency = 313.9 Hz with amplitude 431.0
# frequency = 314.1 Hz with amplitude 614.0
# frequency = 314.3 Hz with amplitude 663.0
# frequency = 314.4 Hz with amplitude 482.0
# frequency = 314.9 Hz with amplitude 457.0
# frequency = 315.1 Hz with amplitude 623.0
# frequency = 315.3 Hz with amplitude 678.0
# frequency = 315.4 Hz with amplitude 494.0
# frequency = 315.7 Hz with amplitude 352.0
# frequency = 315.9 Hz with amplitude 487.0
# frequency = 316.1 Hz with amplitude 637.0
# frequency = 316.3 Hz with amplitude 698.0
# frequency = 316.4 Hz with amplitude 510.0
# frequency = 316.7 Hz with amplitude 366.0
# frequency = 316.9 Hz with amplitude 521.0
# frequency = 317.1 Hz with amplitude 659.0
# frequency = 317.3 Hz with amplitude 725.0
# frequency = 317.4 Hz with amplitude 530.0
# frequency = 317.7 Hz with amplitude 382.0
# frequency = 317.9 Hz with amplitude 560.0
# frequency = 318.1 Hz with amplitude 688.0
# frequency = 318.3 Hz with amplitude 760.0
# frequency = 318.4 Hz with amplitude 556.0
# frequency = 318.7 Hz with amplitude 401.0
# frequency = 318.9 Hz with amplitude 606.0
# frequency = 319.0 Hz with amplitude 388.0
# frequency = 319.1 Hz with amplitude 728.0
# frequency = 319.3 Hz with amplitude 804.0
# frequency = 319.4 Hz with amplitude 588.0
# frequency = 319.7 Hz with amplitude 423.0
# frequency = 319.9 Hz with amplitude 659.0
# frequency = 320.0 Hz with amplitude 458.0
# frequency = 320.1 Hz with amplitude 781.0
# frequency = 320.3 Hz with amplitude 859.0
# frequency = 320.4 Hz with amplitude 629.0
# frequency = 320.7 Hz with amplitude 450.0
# frequency = 320.9 Hz with amplitude 723.0
# frequency = 321.0 Hz with amplitude 543.0
# frequency = 321.1 Hz with amplitude 852.0
# frequency = 321.3 Hz with amplitude 931.0
# frequency = 321.4 Hz with amplitude 682.0
# frequency = 321.7 Hz with amplitude 482.0
# frequency = 321.9 Hz with amplitude 801.0
# frequency = 322.0 Hz with amplitude 648.0
# frequency = 322.1 Hz with amplitude 946.0
# frequency = 322.3 Hz with amplitude 1025.0
# frequency = 322.4 Hz with amplitude 750.0
# frequency = 322.7 Hz with amplitude 522.0
# frequency = 322.9 Hz with amplitude 900.0
# frequency = 323.0 Hz with amplitude 783.0
# frequency = 323.1 Hz with amplitude 1076.0
# frequency = 323.3 Hz with amplitude 1152.0
# frequency = 323.4 Hz with amplitude 841.0
# frequency = 323.7 Hz with amplitude 574.0
# frequency = 323.9 Hz with amplitude 1031.0
# frequency = 324.0 Hz with amplitude 963.0
# frequency = 324.1 Hz with amplitude 1258.0
# frequency = 324.3 Hz with amplitude 1329.0
# frequency = 324.4 Hz with amplitude 968.0
# frequency = 324.6 Hz with amplitude 379.0
# frequency = 324.7 Hz with amplitude 645.0
# frequency = 324.9 Hz with amplitude 1211.0
# frequency = 325.0 Hz with amplitude 1218.0
# frequency = 325.1 Hz with amplitude 1529.0
# frequency = 325.3 Hz with amplitude 1590.0
# frequency = 325.4 Hz with amplitude 1156.0
# frequency = 325.6 Hz with amplitude 433.0
# frequency = 325.7 Hz with amplitude 750.0
# frequency = 325.9 Hz with amplitude 1482.0
# frequency = 326.0 Hz with amplitude 1609.0
# frequency = 326.1 Hz with amplitude 1964.0
# frequency = 326.3 Hz with amplitude 2010.0
# frequency = 326.4 Hz with amplitude 1463.0
# frequency = 326.6 Hz with amplitude 524.0
# frequency = 326.7 Hz with amplitude 921.0
# frequency = 326.9 Hz with amplitude 1940.0
# frequency = 327.0 Hz with amplitude 2293.0
# frequency = 327.1 Hz with amplitude 2761.0
# frequency = 327.3 Hz with amplitude 2795.0
# frequency = 327.4 Hz with amplitude 2049.0
# frequency = 327.6 Hz with amplitude 707.0
# frequency = 327.7 Hz with amplitude 1265.0
# frequency = 327.9 Hz with amplitude 2901.0
# frequency = 328.0 Hz with amplitude 3810.0
# frequency = 328.1 Hz with amplitude 4648.0
# frequency = 328.3 Hz with amplitude 4755.0
# frequency = 328.4 Hz with amplitude 3609.0
# frequency = 328.6 Hz with amplitude 1253.0
# frequency = 328.7 Hz with amplitude 2349.0
# frequency = 328.9 Hz with amplitude 6315.0
# frequency = 329.0 Hz with amplitude 10143.0
# frequency = 329.1 Hz with amplitude 14377.0
# frequency = 329.3 Hz with amplitude 18202.0
# frequency = 329.4 Hz with amplitude 20827.0
# frequency = 329.6 Hz with amplitude 21993.0
# frequency = 329.7 Hz with amplitude 21496.0
# frequency = 329.9 Hz with amplitude 19868.0
# frequency = 330.0 Hz with amplitude 17501.0
# frequency = 330.1 Hz with amplitude 13703.0
# frequency = 330.3 Hz with amplitude 9223.0
# frequency = 330.4 Hz with amplitude 4938.0
# frequency = 330.6 Hz with amplitude 1286.0
# frequency = 330.7 Hz with amplitude 1463.0
# frequency = 330.9 Hz with amplitude 3432.0
# frequency = 331.0 Hz with amplitude 4854.0
# frequency = 331.1 Hz with amplitude 4737.0
# frequency = 331.3 Hz with amplitude 3571.0
# frequency = 331.4 Hz with amplitude 2087.0
# frequency = 331.6 Hz with amplitude 663.0
# frequency = 331.7 Hz with amplitude 650.0
# frequency = 331.9 Hz with amplitude 1719.0
# frequency = 332.0 Hz with amplitude 2866.0
# frequency = 332.1 Hz with amplitude 2910.0
# frequency = 332.3 Hz with amplitude 2173.0
# frequency = 332.4 Hz with amplitude 1268.0
# frequency = 332.6 Hz with amplitude 502.0
# frequency = 332.7 Hz with amplitude 398.0
# frequency = 332.9 Hz with amplitude 1052.0
# frequency = 333.0 Hz with amplitude 2056.0
# frequency = 333.1 Hz with amplitude 2130.0
# frequency = 333.3 Hz with amplitude 1539.0
# frequency = 333.4 Hz with amplitude 877.0
# frequency = 333.6 Hz with amplitude 450.0
# frequency = 333.9 Hz with amplitude 686.0
# frequency = 334.0 Hz with amplitude 1616.0
# frequency = 334.1 Hz with amplitude 1702.0
# frequency = 334.3 Hz with amplitude 1177.0
# frequency = 334.4 Hz with amplitude 646.0
# frequency = 334.6 Hz with amplitude 441.0
# frequency = 334.9 Hz with amplitude 447.0
# frequency = 335.0 Hz with amplitude 1341.0
# frequency = 335.1 Hz with amplitude 1434.0
# frequency = 335.3 Hz with amplitude 942.0
# frequency = 335.4 Hz with amplitude 494.0
# frequency = 335.6 Hz with amplitude 453.0
# frequency = 335.7 Hz with amplitude 354.0
# frequency = 336.0 Hz with amplitude 1154.0
# frequency = 336.1 Hz with amplitude 1254.0
# frequency = 336.3 Hz with amplitude 776.0
# frequency = 336.4 Hz with amplitude 386.0
# frequency = 336.6 Hz with amplitude 478.0
# frequency = 336.7 Hz with amplitude 404.0
# frequency = 337.0 Hz with amplitude 1021.0
# frequency = 337.1 Hz with amplitude 1127.0
# frequency = 337.3 Hz with amplitude 652.0
# frequency = 337.6 Hz with amplitude 513.0
# frequency = 337.7 Hz with amplitude 464.0
# frequency = 338.0 Hz with amplitude 925.0
# frequency = 338.1 Hz with amplitude 1035.0
# frequency = 338.3 Hz with amplitude 554.0
# frequency = 338.6 Hz with amplitude 559.0
# frequency = 338.7 Hz with amplitude 533.0
# frequency = 339.0 Hz with amplitude 857.0
# frequency = 339.1 Hz with amplitude 969.0
# frequency = 339.3 Hz with amplitude 474.0
# frequency = 339.6 Hz with amplitude 616.0
# frequency = 339.7 Hz with amplitude 613.0
# frequency = 340.0 Hz with amplitude 813.0
# frequency = 340.1 Hz with amplitude 923.0
# frequency = 340.3 Hz with amplitude 405.0
# frequency = 340.6 Hz with amplitude 688.0
# frequency = 340.7 Hz with amplitude 709.0
# frequency = 340.9 Hz with amplitude 377.0
# frequency = 341.0 Hz with amplitude 793.0
# frequency = 341.1 Hz with amplitude 894.0
# frequency = 341.6 Hz with amplitude 779.0
# frequency = 341.7 Hz with amplitude 826.0
# frequency = 341.9 Hz with amplitude 515.0
# frequency = 342.0 Hz with amplitude 798.0
# frequency = 342.1 Hz with amplitude 881.0
# frequency = 342.6 Hz with amplitude 899.0
# frequency = 342.7 Hz with amplitude 976.0
# frequency = 342.9 Hz with amplitude 682.0
# frequency = 343.0 Hz with amplitude 837.0
# frequency = 343.1 Hz with amplitude 885.0
# frequency = 343.4 Hz with amplitude 450.0
# frequency = 343.6 Hz with amplitude 1062.0
# frequency = 343.7 Hz with amplitude 1177.0
# frequency = 343.9 Hz with amplitude 897.0
# frequency = 344.0 Hz with amplitude 924.0
# frequency = 344.1 Hz with amplitude 912.0
# frequency = 344.4 Hz with amplitude 600.0
# frequency = 344.6 Hz with amplitude 1296.0
# frequency = 344.7 Hz with amplitude 1464.0
# frequency = 344.9 Hz with amplitude 1195.0
# frequency = 345.0 Hz with amplitude 1085.0
# frequency = 345.1 Hz with amplitude 973.0
# frequency = 345.4 Hz with amplitude 830.0
# frequency = 345.6 Hz with amplitude 1657.0
# frequency = 345.7 Hz with amplitude 1911.0
# frequency = 345.9 Hz with amplitude 1653.0
# frequency = 346.0 Hz with amplitude 1383.0
# frequency = 346.1 Hz with amplitude 1095.0
# frequency = 346.4 Hz with amplitude 1222.0
# frequency = 346.6 Hz with amplitude 2293.0
# frequency = 346.7 Hz with amplitude 2709.0
# frequency = 346.9 Hz with amplitude 2478.0
# frequency = 347.0 Hz with amplitude 1992.0
# frequency = 347.1 Hz with amplitude 1362.0
# frequency = 347.4 Hz with amplitude 2045.0
# frequency = 347.6 Hz with amplitude 3696.0
# frequency = 347.7 Hz with amplitude 4555.0
# frequency = 347.9 Hz with amplitude 4479.0
# frequency = 348.0 Hz with amplitude 3651.0
# frequency = 348.1 Hz with amplitude 2163.0
# frequency = 348.3 Hz with amplitude 1023.0
# frequency = 348.4 Hz with amplitude 4920.0
# frequency = 348.6 Hz with amplitude 9377.0
# frequency = 348.7 Hz with amplitude 13570.0
# frequency = 348.9 Hz with amplitude 17173.0
# frequency = 349.0 Hz with amplitude 20084.0
# frequency = 349.1 Hz with amplitude 22217.0
# frequency = 349.3 Hz with amplitude 22235.0
# frequency = 349.4 Hz with amplitude 20866.0
# frequency = 349.6 Hz with amplitude 18058.0
# frequency = 349.7 Hz with amplitude 14496.0
# frequency = 349.9 Hz with amplitude 10453.0
# frequency = 350.0 Hz with amplitude 6116.0
# frequency = 350.1 Hz with amplitude 1619.0
# frequency = 350.3 Hz with amplitude 1489.0
# frequency = 350.4 Hz with amplitude 3683.0
# frequency = 350.6 Hz with amplitude 4645.0
# frequency = 350.7 Hz with amplitude 4786.0
# frequency = 350.9 Hz with amplitude 4143.0
# frequency = 351.0 Hz with amplitude 2755.0
# frequency = 351.1 Hz with amplitude 574.0
# frequency = 351.3 Hz with amplitude 902.0
# frequency = 351.4 Hz with amplitude 2117.0
# frequency = 351.6 Hz with amplitude 2682.0
# frequency = 351.7 Hz with amplitude 2885.0
# frequency = 351.9 Hz with amplitude 2624.0
# frequency = 352.0 Hz with amplitude 1824.0
# frequency = 352.3 Hz with amplitude 694.0
# frequency = 352.4 Hz with amplitude 1529.0
# frequency = 352.6 Hz with amplitude 1895.0
# frequency = 352.7 Hz with amplitude 2074.0
# frequency = 352.9 Hz with amplitude 1937.0
# frequency = 353.0 Hz with amplitude 1390.0
# frequency = 353.3 Hz with amplitude 587.0
# frequency = 353.4 Hz with amplitude 1221.0
# frequency = 353.6 Hz with amplitude 1471.0
# frequency = 353.7 Hz with amplitude 1624.0
# frequency = 353.9 Hz with amplitude 1542.0
# frequency = 354.0 Hz with amplitude 1138.0
# frequency = 354.3 Hz with amplitude 520.0
# frequency = 354.4 Hz with amplitude 1032.0
# frequency = 354.6 Hz with amplitude 1207.0
# frequency = 354.7 Hz with amplitude 1338.0
# frequency = 354.9 Hz with amplitude 1284.0
# frequency = 355.0 Hz with amplitude 974.0
# frequency = 355.3 Hz with amplitude 475.0
# frequency = 355.4 Hz with amplitude 904.0
# frequency = 355.6 Hz with amplitude 1027.0
# frequency = 355.7 Hz with amplitude 1139.0
# frequency = 355.9 Hz with amplitude 1102.0
# frequency = 356.0 Hz with amplitude 858.0
# frequency = 356.3 Hz with amplitude 442.0
# frequency = 356.4 Hz with amplitude 812.0
# frequency = 356.6 Hz with amplitude 898.0
# frequency = 356.7 Hz with amplitude 993.0
# frequency = 356.9 Hz with amplitude 965.0
# frequency = 357.0 Hz with amplitude 771.0
# frequency = 357.3 Hz with amplitude 417.0
# frequency = 357.4 Hz with amplitude 743.0
# frequency = 357.6 Hz with amplitude 800.0
# frequency = 357.7 Hz with amplitude 882.0
# frequency = 357.9 Hz with amplitude 858.0
# frequency = 358.0 Hz with amplitude 704.0
# frequency = 358.3 Hz with amplitude 398.0
# frequency = 358.4 Hz with amplitude 691.0
# frequency = 358.6 Hz with amplitude 724.0
# frequency = 358.7 Hz with amplitude 794.0
# frequency = 358.9 Hz with amplitude 772.0
# frequency = 359.0 Hz with amplitude 650.0
# frequency = 359.3 Hz with amplitude 383.0
# frequency = 359.4 Hz with amplitude 649.0
# frequency = 359.6 Hz with amplitude 664.0
# frequency = 359.7 Hz with amplitude 723.0
# frequency = 359.9 Hz with amplitude 700.0
# frequency = 360.0 Hz with amplitude 606.0
# frequency = 360.3 Hz with amplitude 371.0
# frequency = 360.4 Hz with amplitude 616.0
# frequency = 360.6 Hz with amplitude 616.0
# frequency = 360.7 Hz with amplitude 665.0
# frequency = 360.9 Hz with amplitude 640.0
# frequency = 361.0 Hz with amplitude 568.0
# frequency = 361.3 Hz with amplitude 362.0
# frequency = 361.4 Hz with amplitude 590.0
# frequency = 361.6 Hz with amplitude 576.0
# frequency = 361.7 Hz with amplitude 616.0
# frequency = 361.9 Hz with amplitude 588.0
# frequency = 362.0 Hz with amplitude 536.0
# frequency = 362.3 Hz with amplitude 355.0
# frequency = 362.4 Hz with amplitude 568.0
# frequency = 362.6 Hz with amplitude 544.0
# frequency = 362.7 Hz with amplitude 574.0
# frequency = 362.9 Hz with amplitude 542.0
# frequency = 363.0 Hz with amplitude 509.0
# frequency = 363.4 Hz with amplitude 551.0
# frequency = 363.6 Hz with amplitude 517.0
# frequency = 363.7 Hz with amplitude 539.0
# frequency = 363.9 Hz with amplitude 502.0
# frequency = 364.0 Hz with amplitude 484.0
# frequency = 364.4 Hz with amplitude 538.0
# frequency = 364.6 Hz with amplitude 495.0
# frequency = 364.7 Hz with amplitude 508.0
# frequency = 364.9 Hz with amplitude 466.0
# frequency = 365.0 Hz with amplitude 463.0
# frequency = 365.4 Hz with amplitude 528.0
# frequency = 365.6 Hz with amplitude 478.0
# frequency = 365.7 Hz with amplitude 482.0
# frequency = 365.9 Hz with amplitude 433.0
# frequency = 366.0 Hz with amplitude 444.0
# frequency = 366.4 Hz with amplitude 520.0
# frequency = 366.6 Hz with amplitude 464.0
# frequency = 366.7 Hz with amplitude 459.0
# frequency = 366.9 Hz with amplitude 403.0
# frequency = 367.0 Hz with amplitude 426.0
# frequency = 367.4 Hz with amplitude 515.0
# frequency = 367.6 Hz with amplitude 453.0
# frequency = 367.7 Hz with amplitude 440.0
# frequency = 367.9 Hz with amplitude 376.0
# frequency = 368.0 Hz with amplitude 410.0
# frequency = 368.4 Hz with amplitude 512.0
# frequency = 368.6 Hz with amplitude 445.0
# frequency = 368.7 Hz with amplitude 423.0
# frequency = 369.0 Hz with amplitude 396.0
# frequency = 369.3 Hz with amplitude 350.0
# frequency = 369.4 Hz with amplitude 512.0
# frequency = 369.6 Hz with amplitude 440.0
# frequency = 369.7 Hz with amplitude 409.0
# frequency = 370.0 Hz with amplitude 382.0
# frequency = 370.3 Hz with amplitude 355.0
# frequency = 370.4 Hz with amplitude 514.0
# frequency = 370.6 Hz with amplitude 438.0
# frequency = 370.7 Hz with amplitude 397.0
# frequency = 371.0 Hz with amplitude 370.0
# frequency = 371.3 Hz with amplitude 361.0
# frequency = 371.4 Hz with amplitude 518.0
# frequency = 371.6 Hz with amplitude 438.0
# frequency = 371.7 Hz with amplitude 388.0
# frequency = 372.0 Hz with amplitude 359.0
# frequency = 372.3 Hz with amplitude 369.0
# frequency = 372.4 Hz with amplitude 525.0
# frequency = 372.6 Hz with amplitude 441.0
# frequency = 372.7 Hz with amplitude 381.0
# frequency = 373.3 Hz with amplitude 379.0
# frequency = 373.4 Hz with amplitude 534.0
# frequency = 373.6 Hz with amplitude 447.0
# frequency = 373.7 Hz with amplitude 377.0
# frequency = 374.3 Hz with amplitude 391.0
# frequency = 374.4 Hz with amplitude 546.0
# frequency = 374.6 Hz with amplitude 457.0
# frequency = 374.7 Hz with amplitude 375.0
# frequency = 375.3 Hz with amplitude 405.0
# frequency = 375.4 Hz with amplitude 561.0
# frequency = 375.6 Hz with amplitude 469.0
# frequency = 375.7 Hz with amplitude 376.0
# frequency = 376.3 Hz with amplitude 421.0
# frequency = 376.4 Hz with amplitude 580.0
# frequency = 376.6 Hz with amplitude 486.0
# frequency = 376.7 Hz with amplitude 381.0
# frequency = 377.3 Hz with amplitude 441.0
# frequency = 377.4 Hz with amplitude 603.0
# frequency = 377.6 Hz with amplitude 506.0
# frequency = 377.7 Hz with amplitude 389.0
# frequency = 378.3 Hz with amplitude 464.0
# frequency = 378.4 Hz with amplitude 630.0
# frequency = 378.6 Hz with amplitude 532.0
# frequency = 378.7 Hz with amplitude 403.0
# frequency = 379.3 Hz with amplitude 492.0
# frequency = 379.4 Hz with amplitude 664.0
# frequency = 379.6 Hz with amplitude 564.0
# frequency = 379.7 Hz with amplitude 421.0
# frequency = 380.3 Hz with amplitude 526.0
# frequency = 380.4 Hz with amplitude 704.0
# frequency = 380.6 Hz with amplitude 604.0
# frequency = 380.7 Hz with amplitude 446.0
# frequency = 381.3 Hz with amplitude 566.0
# frequency = 381.4 Hz with amplitude 754.0
# frequency = 381.6 Hz with amplitude 654.0
# frequency = 381.7 Hz with amplitude 480.0
# frequency = 382.1 Hz with amplitude 360.0
# frequency = 382.3 Hz with amplitude 616.0
# frequency = 382.4 Hz with amplitude 816.0
# frequency = 382.6 Hz with amplitude 716.0
# frequency = 382.7 Hz with amplitude 525.0
# frequency = 383.1 Hz with amplitude 392.0
# frequency = 383.3 Hz with amplitude 678.0
# frequency = 383.4 Hz with amplitude 894.0
# frequency = 383.6 Hz with amplitude 794.0
# frequency = 383.7 Hz with amplitude 584.0
# frequency = 384.1 Hz with amplitude 432.0
# frequency = 384.3 Hz with amplitude 757.0
# frequency = 384.4 Hz with amplitude 994.0
# frequency = 384.6 Hz with amplitude 897.0
# frequency = 384.7 Hz with amplitude 663.0
# frequency = 385.1 Hz with amplitude 486.0
# frequency = 385.3 Hz with amplitude 861.0
# frequency = 385.4 Hz with amplitude 1127.0
# frequency = 385.6 Hz with amplitude 1033.0
# frequency = 385.7 Hz with amplitude 772.0
# frequency = 386.1 Hz with amplitude 559.0
# frequency = 386.3 Hz with amplitude 1003.0
# frequency = 386.4 Hz with amplitude 1310.0
# frequency = 386.6 Hz with amplitude 1223.0
# frequency = 386.7 Hz with amplitude 926.0
# frequency = 387.1 Hz with amplitude 664.0
# frequency = 387.3 Hz with amplitude 1206.0
# frequency = 387.4 Hz with amplitude 1574.0
# frequency = 387.6 Hz with amplitude 1501.0
# frequency = 387.7 Hz with amplitude 1158.0
# frequency = 387.9 Hz with amplitude 489.0
# frequency = 388.1 Hz with amplitude 827.0
# frequency = 388.3 Hz with amplitude 1521.0
# frequency = 388.4 Hz with amplitude 1991.0
# frequency = 388.6 Hz with amplitude 1945.0
# frequency = 388.7 Hz with amplitude 1536.0
# frequency = 388.9 Hz with amplitude 719.0
# frequency = 389.1 Hz with amplitude 1107.0
# frequency = 389.3 Hz with amplitude 2069.0
# frequency = 389.4 Hz with amplitude 2736.0
# frequency = 389.6 Hz with amplitude 2761.0
# frequency = 389.7 Hz with amplitude 2254.0
# frequency = 389.9 Hz with amplitude 1162.0
# frequency = 390.1 Hz with amplitude 1695.0
# frequency = 390.3 Hz with amplitude 3264.0
# frequency = 390.4 Hz with amplitude 4437.0
# frequency = 390.6 Hz with amplitude 4732.0
# frequency = 390.7 Hz with amplitude 4103.0
# frequency = 390.9 Hz with amplitude 2379.0
# frequency = 391.1 Hz with amplitude 3675.0
# frequency = 391.3 Hz with amplitude 7834.0
# frequency = 391.4 Hz with amplitude 12161.0
# frequency = 391.6 Hz with amplitude 16020.0
# frequency = 391.7 Hz with amplitude 19155.0
# frequency = 391.9 Hz with amplitude 21150.0
# frequency = 392.0 Hz with amplitude 22048.0
# frequency = 392.1 Hz with amplitude 21278.0
# frequency = 392.3 Hz with amplitude 19105.0
# frequency = 392.4 Hz with amplitude 15800.0
# frequency = 392.6 Hz with amplitude 11907.0
# frequency = 392.7 Hz with amplitude 7688.0
# frequency = 392.9 Hz with amplitude 3637.0
# frequency = 393.1 Hz with amplitude 2747.0
# frequency = 393.3 Hz with amplitude 4292.0
# frequency = 393.4 Hz with amplitude 4747.0
# frequency = 393.6 Hz with amplitude 4400.0
# frequency = 393.7 Hz with amplitude 3304.0
# frequency = 393.9 Hz with amplitude 1791.0
# frequency = 394.1 Hz with amplitude 1480.0
# frequency = 394.3 Hz with amplitude 2417.0
# frequency = 394.4 Hz with amplitude 2783.0
# frequency = 394.6 Hz with amplitude 2725.0
# frequency = 394.7 Hz with amplitude 2148.0
# frequency = 394.9 Hz with amplitude 1233.0
# frequency = 395.1 Hz with amplitude 1021.0
# frequency = 395.3 Hz with amplitude 1683.0
# frequency = 395.4 Hz with amplitude 1966.0
# frequency = 395.6 Hz with amplitude 1990.0
# frequency = 395.7 Hz with amplitude 1617.0
# frequency = 395.9 Hz with amplitude 962.0
# frequency = 396.1 Hz with amplitude 787.0
# frequency = 396.3 Hz with amplitude 1293.0
# frequency = 396.4 Hz with amplitude 1520.0
# frequency = 396.6 Hz with amplitude 1578.0
# frequency = 396.7 Hz with amplitude 1313.0
# frequency = 396.9 Hz with amplitude 801.0
# frequency = 397.1 Hz with amplitude 645.0
# frequency = 397.3 Hz with amplitude 1052.0
# frequency = 397.4 Hz with amplitude 1240.0
# frequency = 397.6 Hz with amplitude 1316.0
# frequency = 397.7 Hz with amplitude 1116.0
# frequency = 397.9 Hz with amplitude 694.0
# frequency = 398.1 Hz with amplitude 551.0
# frequency = 398.3 Hz with amplitude 888.0
# frequency = 398.4 Hz with amplitude 1048.0
# frequency = 398.6 Hz with amplitude 1135.0
# frequency = 398.7 Hz with amplitude 980.0
# frequency = 398.9 Hz with amplitude 617.0
# frequency = 399.1 Hz with amplitude 485.0
# frequency = 399.3 Hz with amplitude 771.0
# frequency = 399.4 Hz with amplitude 910.0
# frequency = 399.6 Hz with amplitude 1004.0
# frequency = 399.7 Hz with amplitude 880.0
# frequency = 399.9 Hz with amplitude 558.0
# frequency = 400.1 Hz with amplitude 437.0
# frequency = 400.3 Hz with amplitude 682.0
# frequency = 400.4 Hz with amplitude 805.0
# frequency = 400.6 Hz with amplitude 904.0
# frequency = 400.7 Hz with amplitude 803.0
# frequency = 400.9 Hz with amplitude 512.0
# frequency = 401.1 Hz with amplitude 400.0
# frequency = 401.3 Hz with amplitude 614.0
# frequency = 401.4 Hz with amplitude 724.0
# frequency = 401.6 Hz with amplitude 827.0
# frequency = 401.7 Hz with amplitude 744.0
# frequency = 401.9 Hz with amplitude 475.0
# frequency = 402.1 Hz with amplitude 372.0
# frequency = 402.3 Hz with amplitude 559.0
# frequency = 402.4 Hz with amplitude 659.0
# frequency = 402.6 Hz with amplitude 765.0
# frequency = 402.7 Hz with amplitude 696.0
# frequency = 402.9 Hz with amplitude 444.0
# frequency = 403.3 Hz with amplitude 515.0
# frequency = 403.4 Hz with amplitude 607.0
# frequency = 403.6 Hz with amplitude 715.0
# frequency = 403.7 Hz with amplitude 658.0
# frequency = 403.9 Hz with amplitude 418.0
# frequency = 404.3 Hz with amplitude 479.0
# frequency = 404.4 Hz with amplitude 564.0
# frequency = 404.6 Hz with amplitude 674.0
# frequency = 404.7 Hz with amplitude 626.0
# frequency = 404.9 Hz with amplitude 396.0
# frequency = 405.3 Hz with amplitude 449.0
# frequency = 405.4 Hz with amplitude 529.0
# frequency = 405.6 Hz with amplitude 640.0
# frequency = 405.7 Hz with amplitude 599.0
# frequency = 405.9 Hz with amplitude 376.0
# frequency = 406.3 Hz with amplitude 424.0
# frequency = 406.4 Hz with amplitude 499.0
# frequency = 406.6 Hz with amplitude 612.0
# frequency = 406.7 Hz with amplitude 578.0
# frequency = 406.9 Hz with amplitude 359.0
# frequency = 407.3 Hz with amplitude 403.0
# frequency = 407.4 Hz with amplitude 475.0
# frequency = 407.6 Hz with amplitude 589.0
# frequency = 407.7 Hz with amplitude 559.0
# frequency = 408.3 Hz with amplitude 385.0
# frequency = 408.4 Hz with amplitude 454.0
# frequency = 408.6 Hz with amplitude 569.0
# frequency = 408.7 Hz with amplitude 544.0
# frequency = 409.3 Hz with amplitude 370.0
# frequency = 409.4 Hz with amplitude 437.0
# frequency = 409.6 Hz with amplitude 553.0
# frequency = 409.7 Hz with amplitude 531.0
# frequency = 410.3 Hz with amplitude 358.0
# frequency = 410.4 Hz with amplitude 423.0
# frequency = 410.6 Hz with amplitude 540.0
# frequency = 410.7 Hz with amplitude 521.0
# frequency = 411.4 Hz with amplitude 412.0
# frequency = 411.6 Hz with amplitude 530.0
# frequency = 411.7 Hz with amplitude 512.0
# frequency = 412.4 Hz with amplitude 403.0
# frequency = 412.6 Hz with amplitude 522.0
# frequency = 412.7 Hz with amplitude 506.0
# frequency = 413.4 Hz with amplitude 396.0
# frequency = 413.6 Hz with amplitude 516.0
# frequency = 413.7 Hz with amplitude 501.0
# frequency = 414.4 Hz with amplitude 391.0
# frequency = 414.6 Hz with amplitude 512.0
# frequency = 414.7 Hz with amplitude 498.0
# frequency = 415.4 Hz with amplitude 388.0
# frequency = 415.6 Hz with amplitude 510.0
# frequency = 415.7 Hz with amplitude 496.0
# frequency = 416.4 Hz with amplitude 387.0
# frequency = 416.6 Hz with amplitude 510.0
# frequency = 416.7 Hz with amplitude 496.0
# frequency = 417.4 Hz with amplitude 389.0
# frequency = 417.6 Hz with amplitude 512.0
# frequency = 417.7 Hz with amplitude 497.0
# frequency = 418.4 Hz with amplitude 392.0
# frequency = 418.6 Hz with amplitude 516.0
# frequency = 418.7 Hz with amplitude 500.0
# frequency = 419.4 Hz with amplitude 397.0
# frequency = 419.6 Hz with amplitude 522.0
# frequency = 419.7 Hz with amplitude 505.0
# frequency = 420.4 Hz with amplitude 404.0
# frequency = 420.6 Hz with amplitude 530.0
# frequency = 420.7 Hz with amplitude 511.0
# frequency = 421.4 Hz with amplitude 414.0
# frequency = 421.6 Hz with amplitude 541.0
# frequency = 421.7 Hz with amplitude 519.0
# frequency = 422.4 Hz with amplitude 426.0
# frequency = 422.6 Hz with amplitude 554.0
# frequency = 422.7 Hz with amplitude 530.0
# frequency = 423.3 Hz with amplitude 359.0
# frequency = 423.4 Hz with amplitude 441.0
# frequency = 423.6 Hz with amplitude 570.0
# frequency = 423.7 Hz with amplitude 543.0
# frequency = 424.3 Hz with amplitude 373.0
# frequency = 424.4 Hz with amplitude 460.0
# frequency = 424.6 Hz with amplitude 590.0
# frequency = 424.7 Hz with amplitude 558.0
# frequency = 425.3 Hz with amplitude 390.0
# frequency = 425.4 Hz with amplitude 483.0
# frequency = 425.6 Hz with amplitude 614.0
# frequency = 425.7 Hz with amplitude 577.0
# frequency = 426.3 Hz with amplitude 411.0
# frequency = 426.4 Hz with amplitude 510.0
# frequency = 426.6 Hz with amplitude 643.0
# frequency = 426.7 Hz with amplitude 600.0
# frequency = 427.3 Hz with amplitude 436.0
# frequency = 427.4 Hz with amplitude 543.0
# frequency = 427.6 Hz with amplitude 678.0
# frequency = 427.7 Hz with amplitude 628.0
# frequency = 428.1 Hz with amplitude 355.0
# frequency = 428.3 Hz with amplitude 466.0
# frequency = 428.4 Hz with amplitude 584.0
# frequency = 428.6 Hz with amplitude 720.0
# frequency = 428.7 Hz with amplitude 663.0
# frequency = 429.1 Hz with amplitude 376.0
# frequency = 429.3 Hz with amplitude 504.0
# frequency = 429.4 Hz with amplitude 634.0
# frequency = 429.6 Hz with amplitude 772.0
# frequency = 429.7 Hz with amplitude 705.0
# frequency = 430.1 Hz with amplitude 401.0
# frequency = 430.3 Hz with amplitude 551.0
# frequency = 430.4 Hz with amplitude 695.0
# frequency = 430.6 Hz with amplitude 836.0
# frequency = 430.7 Hz with amplitude 757.0
# frequency = 431.1 Hz with amplitude 433.0
# frequency = 431.3 Hz with amplitude 611.0
# frequency = 431.4 Hz with amplitude 773.0
# frequency = 431.6 Hz with amplitude 916.0
# frequency = 431.7 Hz with amplitude 823.0
# frequency = 432.1 Hz with amplitude 473.0
# frequency = 432.3 Hz with amplitude 687.0
# frequency = 432.4 Hz with amplitude 872.0
# frequency = 432.6 Hz with amplitude 1020.0
# frequency = 432.7 Hz with amplitude 909.0
# frequency = 432.9 Hz with amplitude 384.0
# frequency = 433.1 Hz with amplitude 526.0
# frequency = 433.3 Hz with amplitude 788.0
# frequency = 433.4 Hz with amplitude 1004.0
# frequency = 433.6 Hz with amplitude 1159.0
# frequency = 433.7 Hz with amplitude 1024.0
# frequency = 433.9 Hz with amplitude 446.0
# frequency = 434.1 Hz with amplitude 599.0
# frequency = 434.3 Hz with amplitude 926.0
# frequency = 434.4 Hz with amplitude 1186.0
# frequency = 434.6 Hz with amplitude 1350.0
# frequency = 434.7 Hz with amplitude 1184.0
# frequency = 434.9 Hz with amplitude 535.0
# frequency = 435.1 Hz with amplitude 702.0
# frequency = 435.3 Hz with amplitude 1124.0
# frequency = 435.4 Hz with amplitude 1449.0
# frequency = 435.6 Hz with amplitude 1630.0
# frequency = 435.7 Hz with amplitude 1422.0
# frequency = 435.9 Hz with amplitude 672.0
# frequency = 436.1 Hz with amplitude 861.0
# frequency = 436.3 Hz with amplitude 1433.0
# frequency = 436.4 Hz with amplitude 1863.0
# frequency = 436.6 Hz with amplitude 2076.0
# frequency = 436.7 Hz with amplitude 1807.0
# frequency = 436.9 Hz with amplitude 900.0
# frequency = 437.1 Hz with amplitude 1133.0
# frequency = 437.3 Hz with amplitude 1972.0
# frequency = 437.4 Hz with amplitude 2603.0
# frequency = 437.6 Hz with amplitude 2893.0
# frequency = 437.7 Hz with amplitude 2533.0
# frequency = 437.9 Hz with amplitude 1347.0
# frequency = 438.1 Hz with amplitude 1702.0
# frequency = 438.3 Hz with amplitude 3147.0
# frequency = 438.4 Hz with amplitude 4292.0
# frequency = 438.6 Hz with amplitude 4860.0
# frequency = 438.7 Hz with amplitude 4395.0
# frequency = 438.9 Hz with amplitude 2586.0
# frequency = 439.1 Hz with amplitude 3611.0
# frequency = 439.3 Hz with amplitude 7623.0
# frequency = 439.4 Hz with amplitude 11907.0
# frequency = 439.6 Hz with amplitude 16032.0
# frequency = 439.7 Hz with amplitude 19328.0
# frequency = 439.9 Hz with amplitude 21234.0
# frequency = 440.0 Hz with amplitude 22036.0
# frequency = 440.1 Hz with amplitude 21262.0
# frequency = 440.3 Hz with amplitude 19269.0
# frequency = 440.4 Hz with amplitude 16038.0
# frequency = 440.6 Hz with amplitude 11913.0
# frequency = 440.7 Hz with amplitude 7564.0
# frequency = 440.9 Hz with amplitude 3638.0
# frequency = 441.1 Hz with amplitude 2616.0
# frequency = 441.3 Hz with amplitude 4336.0
# frequency = 441.4 Hz with amplitude 4867.0
# frequency = 441.6 Hz with amplitude 4297.0
# frequency = 441.7 Hz with amplitude 3087.0
# frequency = 441.9 Hz with amplitude 1728.0
# frequency = 442.1 Hz with amplitude 1377.0
# frequency = 442.3 Hz with amplitude 2473.0
# frequency = 442.4 Hz with amplitude 2900.0
# frequency = 442.6 Hz with amplitude 2608.0
# frequency = 442.7 Hz with amplitude 1913.0
# frequency = 442.9 Hz with amplitude 1157.0
# frequency = 443.1 Hz with amplitude 931.0
# frequency = 443.3 Hz with amplitude 1747.0
# frequency = 443.4 Hz with amplitude 2083.0
# frequency = 443.6 Hz with amplitude 1868.0
# frequency = 443.7 Hz with amplitude 1373.0
# frequency = 443.9 Hz with amplitude 883.0
# frequency = 444.1 Hz with amplitude 702.0
# frequency = 444.3 Hz with amplitude 1362.0
# frequency = 444.4 Hz with amplitude 1637.0
# frequency = 444.6 Hz with amplitude 1453.0
# frequency = 444.7 Hz with amplitude 1065.0
# frequency = 444.9 Hz with amplitude 722.0
# frequency = 445.1 Hz with amplitude 565.0
# frequency = 445.3 Hz with amplitude 1125.0
# frequency = 445.4 Hz with amplitude 1357.0
# frequency = 445.6 Hz with amplitude 1189.0
# frequency = 445.7 Hz with amplitude 866.0
# frequency = 445.9 Hz with amplitude 617.0
# frequency = 446.1 Hz with amplitude 475.0
# frequency = 446.3 Hz with amplitude 964.0
# frequency = 446.4 Hz with amplitude 1166.0
# frequency = 446.6 Hz with amplitude 1006.0
# frequency = 446.7 Hz with amplitude 728.0
# frequency = 446.9 Hz with amplitude 543.0
# frequency = 447.1 Hz with amplitude 412.0
# frequency = 447.3 Hz with amplitude 849.0
# frequency = 447.4 Hz with amplitude 1027.0
# frequency = 447.6 Hz with amplitude 873.0
# frequency = 447.7 Hz with amplitude 627.0
# frequency = 447.9 Hz with amplitude 487.0
# frequency = 448.1 Hz with amplitude 366.0
# frequency = 448.3 Hz with amplitude 763.0
# frequency = 448.4 Hz with amplitude 923.0
# frequency = 448.6 Hz with amplitude 772.0
# frequency = 448.7 Hz with amplitude 550.0
# frequency = 448.9 Hz with amplitude 444.0
# frequency = 449.3 Hz with amplitude 696.0
# frequency = 449.4 Hz with amplitude 842.0
# frequency = 449.6 Hz with amplitude 694.0
# frequency = 449.7 Hz with amplitude 491.0
# frequency = 449.9 Hz with amplitude 410.0
# frequency = 450.3 Hz with amplitude 644.0
# frequency = 450.4 Hz with amplitude 777.0
# frequency = 450.6 Hz with amplitude 631.0
# frequency = 450.7 Hz with amplitude 443.0
# frequency = 450.9 Hz with amplitude 382.0
# frequency = 451.3 Hz with amplitude 601.0
# frequency = 451.4 Hz with amplitude 725.0
# frequency = 451.6 Hz with amplitude 580.0
# frequency = 451.7 Hz with amplitude 405.0
# frequency = 451.9 Hz with amplitude 359.0
# frequency = 452.3 Hz with amplitude 567.0
# frequency = 452.4 Hz with amplitude 682.0
# frequency = 452.6 Hz with amplitude 538.0
# frequency = 452.7 Hz with amplitude 373.0
# frequency = 453.3 Hz with amplitude 538.0
# frequency = 453.4 Hz with amplitude 646.0
# frequency = 453.6 Hz with amplitude 502.0
# frequency = 454.3 Hz with amplitude 515.0
# frequency = 454.4 Hz with amplitude 617.0
# frequency = 454.6 Hz with amplitude 473.0
# frequency = 455.3 Hz with amplitude 495.0
# frequency = 455.4 Hz with amplitude 592.0
# frequency = 455.6 Hz with amplitude 448.0
# frequency = 456.3 Hz with amplitude 479.0
# frequency = 456.4 Hz with amplitude 571.0
# frequency = 456.6 Hz with amplitude 427.0
# frequency = 457.3 Hz with amplitude 465.0
# frequency = 457.4 Hz with amplitude 553.0
# frequency = 457.6 Hz with amplitude 409.0
# frequency = 458.3 Hz with amplitude 454.0
# frequency = 458.4 Hz with amplitude 538.0
# frequency = 458.6 Hz with amplitude 394.0
# frequency = 459.3 Hz with amplitude 444.0
# frequency = 459.4 Hz with amplitude 525.0
# frequency = 459.6 Hz with amplitude 382.0
# frequency = 460.3 Hz with amplitude 437.0
# frequency = 460.4 Hz with amplitude 515.0
# frequency = 460.6 Hz with amplitude 371.0
# frequency = 461.3 Hz with amplitude 431.0
# frequency = 461.4 Hz with amplitude 507.0
# frequency = 461.6 Hz with amplitude 363.0
# frequency = 462.3 Hz with amplitude 427.0
# frequency = 462.4 Hz with amplitude 500.0
# frequency = 462.6 Hz with amplitude 356.0
# frequency = 463.3 Hz with amplitude 424.0
# frequency = 463.4 Hz with amplitude 495.0
# frequency = 463.6 Hz with amplitude 350.0
# frequency = 464.3 Hz with amplitude 422.0
# frequency = 464.4 Hz with amplitude 492.0
# frequency = 465.3 Hz with amplitude 422.0
# frequency = 465.4 Hz with amplitude 490.0
# frequency = 466.3 Hz with amplitude 423.0
# frequency = 466.4 Hz with amplitude 489.0
# frequency = 467.3 Hz with amplitude 425.0
# frequency = 467.4 Hz with amplitude 490.0
# frequency = 468.3 Hz with amplitude 428.0
# frequency = 468.4 Hz with amplitude 492.0
# frequency = 469.3 Hz with amplitude 433.0
# frequency = 469.4 Hz with amplitude 496.0
# frequency = 470.3 Hz with amplitude 439.0
# frequency = 470.4 Hz with amplitude 501.0
# frequency = 470.6 Hz with amplitude 350.0
# frequency = 471.3 Hz with amplitude 446.0
# frequency = 471.4 Hz with amplitude 507.0
# frequency = 471.6 Hz with amplitude 356.0
# frequency = 472.3 Hz with amplitude 455.0
# frequency = 472.4 Hz with amplitude 516.0
# frequency = 472.6 Hz with amplitude 362.0
# frequency = 473.3 Hz with amplitude 465.0
# frequency = 473.4 Hz with amplitude 526.0
# frequency = 473.6 Hz with amplitude 371.0
# frequency = 474.3 Hz with amplitude 477.0
# frequency = 474.4 Hz with amplitude 538.0
# frequency = 474.6 Hz with amplitude 381.0
# frequency = 475.3 Hz with amplitude 492.0
# frequency = 475.4 Hz with amplitude 552.0
# frequency = 475.6 Hz with amplitude 393.0
# frequency = 476.3 Hz with amplitude 508.0
# frequency = 476.4 Hz with amplitude 569.0
# frequency = 476.6 Hz with amplitude 407.0
# frequency = 477.1 Hz with amplitude 355.0
# frequency = 477.3 Hz with amplitude 527.0
# frequency = 477.4 Hz with amplitude 588.0
# frequency = 477.6 Hz with amplitude 424.0
# frequency = 478.1 Hz with amplitude 373.0
# frequency = 478.3 Hz with amplitude 550.0
# frequency = 478.4 Hz with amplitude 611.0
# frequency = 478.6 Hz with amplitude 444.0
# frequency = 479.1 Hz with amplitude 395.0
# frequency = 479.3 Hz with amplitude 576.0
# frequency = 479.4 Hz with amplitude 638.0
# frequency = 479.6 Hz with amplitude 467.0
# frequency = 480.1 Hz with amplitude 419.0
# frequency = 480.3 Hz with amplitude 606.0
# frequency = 480.4 Hz with amplitude 670.0
# frequency = 480.6 Hz with amplitude 494.0
# frequency = 481.1 Hz with amplitude 448.0
# frequency = 481.3 Hz with amplitude 643.0
# frequency = 481.4 Hz with amplitude 708.0
# frequency = 481.6 Hz with amplitude 527.0
# frequency = 481.7 Hz with amplitude 360.0
# frequency = 482.1 Hz with amplitude 482.0
# frequency = 482.3 Hz with amplitude 686.0
# frequency = 482.4 Hz with amplitude 753.0
# frequency = 482.6 Hz with amplitude 566.0
# frequency = 482.7 Hz with amplitude 385.0
# frequency = 483.1 Hz with amplitude 522.0
# frequency = 483.3 Hz with amplitude 737.0
# frequency = 483.4 Hz with amplitude 808.0
# frequency = 483.6 Hz with amplitude 613.0
# frequency = 483.7 Hz with amplitude 415.0
# frequency = 484.1 Hz with amplitude 570.0
# frequency = 484.3 Hz with amplitude 801.0
# frequency = 484.4 Hz with amplitude 875.0
# frequency = 484.6 Hz with amplitude 672.0
# frequency = 484.7 Hz with amplitude 452.0
# frequency = 485.1 Hz with amplitude 630.0
# frequency = 485.3 Hz with amplitude 879.0
# frequency = 485.4 Hz with amplitude 959.0
# frequency = 485.6 Hz with amplitude 745.0
# frequency = 485.7 Hz with amplitude 499.0
# frequency = 486.1 Hz with amplitude 705.0
# frequency = 486.3 Hz with amplitude 979.0
# frequency = 486.4 Hz with amplitude 1066.0
# frequency = 486.6 Hz with amplitude 838.0
# frequency = 486.7 Hz with amplitude 559.0
# frequency = 487.1 Hz with amplitude 803.0
# frequency = 487.3 Hz with amplitude 1111.0
# frequency = 487.4 Hz with amplitude 1207.0
# frequency = 487.6 Hz with amplitude 963.0
# frequency = 487.7 Hz with amplitude 638.0
# frequency = 488.0 Hz with amplitude 378.0
# frequency = 488.1 Hz with amplitude 934.0
# frequency = 488.3 Hz with amplitude 1290.0
# frequency = 488.4 Hz with amplitude 1402.0
# frequency = 488.6 Hz with amplitude 1134.0
# frequency = 488.7 Hz with amplitude 749.0
# frequency = 489.0 Hz with amplitude 465.0
# frequency = 489.1 Hz with amplitude 1122.0
# frequency = 489.3 Hz with amplitude 1548.0
# frequency = 489.4 Hz with amplitude 1685.0
# frequency = 489.6 Hz with amplitude 1387.0
# frequency = 489.7 Hz with amplitude 913.0
# frequency = 490.0 Hz with amplitude 597.0
# frequency = 490.1 Hz with amplitude 1409.0
# frequency = 490.3 Hz with amplitude 1950.0
# frequency = 490.4 Hz with amplitude 2134.0
# frequency = 490.6 Hz with amplitude 1793.0
# frequency = 490.7 Hz with amplitude 1181.0
# frequency = 491.0 Hz with amplitude 820.0
# frequency = 491.1 Hz with amplitude 1908.0
# frequency = 491.3 Hz with amplitude 2664.0
# frequency = 491.4 Hz with amplitude 2951.0
# frequency = 491.6 Hz with amplitude 2553.0
# frequency = 491.7 Hz with amplitude 1697.0
# frequency = 492.0 Hz with amplitude 1283.0
# frequency = 492.1 Hz with amplitude 2979.0
# frequency = 492.3 Hz with amplitude 4275.0
# frequency = 492.4 Hz with amplitude 4895.0
# frequency = 492.6 Hz with amplitude 4473.0
# frequency = 492.7 Hz with amplitude 3098.0
# frequency = 492.9 Hz with amplitude 538.0
# frequency = 493.0 Hz with amplitude 2794.0
# frequency = 493.1 Hz with amplitude 6943.0
# frequency = 493.3 Hz with amplitude 11282.0
# frequency = 493.4 Hz with amplitude 15395.0
# frequency = 493.6 Hz with amplitude 18716.0
# frequency = 493.7 Hz with amplitude 21085.0
# frequency = 493.9 Hz with amplitude 21982.0
# frequency = 494.0 Hz with amplitude 21613.0
# frequency = 494.1 Hz with amplitude 19643.0
# frequency = 494.3 Hz with amplitude 16545.0
# frequency = 494.4 Hz with amplitude 12627.0
# frequency = 494.6 Hz with amplitude 8442.0
# frequency = 494.7 Hz with amplitude 4220.0
# frequency = 494.9 Hz with amplitude 649.0
# frequency = 495.0 Hz with amplitude 2308.0
# frequency = 495.1 Hz with amplitude 4015.0
# frequency = 495.3 Hz with amplitude 4690.0
# frequency = 495.4 Hz with amplitude 4384.0
# frequency = 495.6 Hz with amplitude 3426.0
# frequency = 495.7 Hz with amplitude 1885.0
# frequency = 495.9 Hz with amplitude 361.0
# frequency = 496.0 Hz with amplitude 1244.0
# frequency = 496.1 Hz with amplitude 2220.0
# frequency = 496.3 Hz with amplitude 2705.0
# frequency = 496.4 Hz with amplitude 2619.0
# frequency = 496.6 Hz with amplitude 2143.0
# frequency = 496.7 Hz with amplitude 1200.0
# frequency = 497.0 Hz with amplitude 863.0
# frequency = 497.1 Hz with amplitude 1526.0
# frequency = 497.3 Hz with amplitude 1888.0
# frequency = 497.4 Hz with amplitude 1851.0
# frequency = 497.6 Hz with amplitude 1556.0
# frequency = 497.7 Hz with amplitude 872.0
# frequency = 498.0 Hz with amplitude 667.0
# frequency = 498.1 Hz with amplitude 1158.0
# frequency = 498.3 Hz with amplitude 1443.0
# frequency = 498.4 Hz with amplitude 1422.0
# frequency = 498.6 Hz with amplitude 1220.0
# frequency = 498.7 Hz with amplitude 681.0
# frequency = 499.0 Hz with amplitude 548.0
# frequency = 499.1 Hz with amplitude 931.0
# frequency = 499.3 Hz with amplitude 1163.0
# frequency = 499.4 Hz with amplitude 1148.0
# frequency = 499.6 Hz with amplitude 1003.0
# frequency = 499.7 Hz with amplitude 555.0
# frequency = 500.0 Hz with amplitude 468.0
# frequency = 500.1 Hz with amplitude 776.0
# frequency = 500.3 Hz with amplitude 971.0
# frequency = 500.4 Hz with amplitude 958.0
# frequency = 500.6 Hz with amplitude 851.0
# frequency = 500.7 Hz with amplitude 467.0
# frequency = 501.0 Hz with amplitude 411.0
# frequency = 501.1 Hz with amplitude 663.0
# frequency = 501.3 Hz with amplitude 831.0
# frequency = 501.4 Hz with amplitude 819.0
# frequency = 501.6 Hz with amplitude 739.0
# frequency = 501.7 Hz with amplitude 401.0
# frequency = 502.0 Hz with amplitude 368.0
# frequency = 502.1 Hz with amplitude 578.0
# frequency = 502.3 Hz with amplitude 725.0
# frequency = 502.4 Hz with amplitude 713.0
# frequency = 502.6 Hz with amplitude 652.0
# frequency = 503.1 Hz with amplitude 512.0
# frequency = 503.3 Hz with amplitude 641.0
# frequency = 503.4 Hz with amplitude 629.0
# frequency = 503.6 Hz with amplitude 584.0
# frequency = 504.1 Hz with amplitude 458.0
# frequency = 504.3 Hz with amplitude 574.0
# frequency = 504.4 Hz with amplitude 562.0
# frequency = 504.6 Hz with amplitude 529.0
# frequency = 505.1 Hz with amplitude 414.0
# frequency = 505.3 Hz with amplitude 519.0
# frequency = 505.4 Hz with amplitude 506.0
# frequency = 505.6 Hz with amplitude 483.0
# frequency = 506.1 Hz with amplitude 377.0
# frequency = 506.3 Hz with amplitude 473.0
# frequency = 506.4 Hz with amplitude 460.0
# frequency = 506.6 Hz with amplitude 444.0
# frequency = 507.3 Hz with amplitude 434.0
# frequency = 507.4 Hz with amplitude 420.0
# frequency = 507.6 Hz with amplitude 411.0
# frequency = 508.3 Hz with amplitude 400.0
# frequency = 508.4 Hz with amplitude 386.0
# frequency = 508.6 Hz with amplitude 383.0
# frequency = 509.3 Hz with amplitude 371.0
# frequency = 509.4 Hz with amplitude 357.0
# frequency = 509.6 Hz with amplitude 359.0

# %%
for i,f in enumerate(frequencies):
    if f < 220 or f > 1000:
        fft_spectrum[i] = 0.0
        
plt.plot(frequencies[:4000], np.abs(fft_spectrum[:4000]))
plt.xlabel("Frequency")
plt.ylabel("Amplitude")
plt.show()

# %%
noiseless_signal = np.fft.irfft(fft_spectrum)
wavfile.write('c_major_noiseless.wav', sampFreq, noiseless_signal)

# %%
spectrums = []
for y in notes:
    y_i = np.fft.fft(y)[0:int(N / 2)]/ N
#     y_i = y_i[0:int(N / 2)]/ N
    y_i[1:] = 2 * y_i[1:]
    note = np.abs(y_i)
    spectrums.append(note[:1000])

# f = np.arange((8 * N / 2000))
fig,ax = plt.subplots()
# ax.set_xscale('log')
# ax.set_yscale('log')
plt.ylabel('Magnitude')
plt.xlabel('Frequency')
# f = np.arange(7 * N)
Y = np.concatenate(spectrums)
f = np.linspace(0, (max(Y) * 2), num=len(Y))#sample_rate * np.arange((N / 2)) / N
plt.plot(f, Y)
# plt.plot(np.concatenate(spectrums)[::1000])
plt.show()

# %%
len(spectrums[0])
# Out:
# 44100

# %%
yf = fft(normalized_tone)
xf = fftfreq(sample_rate, sample_period)

plt.plot(xf, np.abs(yf))
plt.show()

# %%
# notes = []
from scipy.fft import fft, fftfreq
notes_for_visual = []
x = []
for y in notes:
#     spectre = np.zeros(int(sample_rate / 2))
#     spectre[int(v)] = sample_rate / 2
    yf = np.abs(fft(y))
    xf = fftfreq(sample_rate, sample_period)
#     note = np.fft.irfft(spectre)
    notes_for_visual.append(yf[:1000])
    x.append(xf[:1000])
fig,ax = plt.subplots()
# ax.set_xscale('log')
plt.ylabel('Power')
plt.xlabel('Frequency [Hz]')
plt.plot(np.concatenate(x), np.concatenate(notes_for_visual))
plt.show()  
#     notes.append(np.tile(note, duration))
#     notes_for_visual.append(note[:1000])
# plt.plot(np.concatenate(notes)[::1000])
# plt.show()
# plt.plot(np.concatenate(notes_for_visual))
# plt.show()
# wave.write('test2.wav', rate, np.concatenate(notes))
