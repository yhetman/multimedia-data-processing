# %%
from gluoncv import model_zoo, data, utils
from matplotlib import pyplot as plt

# %%
net = model_zoo.get_model('yolo3_darknet53_voc', pretrained=True)
# Out:
# Downloading /home/yhetman/.mxnet/models/yolo3_darknet53_voc-f5ece5ce.zip from https://apache-mxnet.s3-accelerate.dualstack.amazonaws.com/gluon/models/yolo3_darknet53_voc-f5ece5ce.zip...
# 223070KB [00:51, 4300.45KB/s]

# %%
# im_fname = utils.download('2023-02-15_15-09.png')
x, img = data.transforms.presets.yolo.load_test('../videos/2023-02-15_15-09.png', short=512)
print('Shape of pre-processed image:', x.shape)
type(im_fname)
# Out:
# Shape of pre-processed image: (1, 3, 512, 572)
# str

# %%
class_IDs, scores, bounding_boxs = net(x)

ax = utils.viz.plot_bbox(img, bounding_boxs[0], scores[0],
                         class_IDs[0], class_names=net.classes)
plt.show()
